# %%
class Atm:

    def __init__(self):
        self.__pin = ""
        self.__balance = 0
        self.__menu()


    def get_pin(self):
        return self.__pin
    
    def set_pin(self,new_pin):
        if(type(new_pin) == str):
            self.__pin = new_pin
            print("Pin Changed Successfully!!!")

        else:
            print("Not Allowed")


    def __menu(self):
        user_input = int(input('''
        Hello , how would you like to proceed?
        1. Enter 1 to create a pin
        2. Enter 2 to deposite
        3. Enter 3 to withdraw
        4. Enter 4 to check balance
        5. Enter 5 to Exit
'''))
        
        if (user_input == 1):
            self.create_pin()
        elif(user_input == 2):
            self.deposite()
        elif(user_input == 3):
            self.withdraw()
        elif(user_input == 4):
            self.check_balance()
        else:
            print("Thank you !!!")
            


    def create_pin(self):
        self.__pin = input("Create your Atm PIN: ")
        print("Pin Created Successfull !!!!")
        self.__menu()
        

    def deposite(self):
        temp = input("Enter Atm pin: ")
        if(temp == self.__pin):
            amount = int(input("Enter the money you want to deposite: "))
            self.__balance += amount
            print("balance updated Successfully !!!")
        else:
            print("Incorrect Pin")

        self.__menu()


    def withdraw(self):
        temp = input("Enter Atm pin: ")
        if(temp == self.__pin):
            amount = int(input("Enter the amount you want to withdraw: "))
            if(amount<=self.__balance):
                self.__balance = self.__balance-amount
                print("Withdraw Successfull")
            else:
                print("Insufficient Balance!!!")
        else:
            print("Incorrect Pin")

        self.__menu()


    def check_balance(self):
        temp = input("Enter Atm Pin: ")
        if(temp == self.__pin):
            print("Balance: ",self.__balance)
        else:
            print("Incorrect Pin")

        self.__menu()

# %%
#### sbi = Atm()
print(sbi)
# Out:
#         Hello , how would you like to proceed?
#         1. Enter 1 to create a pin
#         2. Enter 2 to deposite
#         3. Enter 3 to withdraw
#         4. Enter 4 to check balance
#         5. Enter 5 to Exit
#  1
# Create your Atm PIN:  2330
# Pin Created Successfull !!!!
#         Hello , how would you like to proceed?
#         1. Enter 1 to create a pin
#         2. Enter 2 to deposite
#         3. Enter 3 to withdraw
#         4. Enter 4 to check balance
#         5. Enter 5 to Exit
#  2
# Enter Atm pin:  2330
# Enter the money you want to deposite:  1200
# balance updated Successfully !!!
#         Hello , how would you like to proceed?
#         1. Enter 1 to create a pin
#         2. Enter 2 to deposite
#         3. Enter 3 to withdraw
#         4. Enter 4 to check balance
#         5. Enter 5 to Exit
#  4
# Enter Atm Pin:  2333
# Incorrect Pin
#         Hello , how would you like to proceed?
#         1. Enter 1 to create a pin
#         2. Enter 2 to deposite
# ...
