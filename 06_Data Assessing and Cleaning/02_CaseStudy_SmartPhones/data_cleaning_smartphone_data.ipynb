# %%
import numpy as np
import pandas as pd

# %%
data = pd.read_csv("smartphones - smartphones.csv")

# %%
df = data.copy()
df.head()
# Out:
#                        model    price  rating  \
# 0              OnePlus 11 5G  ₹54,999    89.0
# 1  OnePlus Nord CE 2 Lite 5G  ₹19,989    81.0
# 2      Samsung Galaxy A14 5G  ₹16,499    75.0
# 3       Motorola Moto G62 5G  ₹14,999    81.0
# 4         Realme 10 Pro Plus  ₹24,999    82.0
#
#                                        sim  \
# 0  Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 1       Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi
# 2       Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi
# 3       Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi
# 4       Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi
#
#                                          processor                        ram  \
# 0  Snapdragon 8 Gen2, Octa Core, 3.2 GHz Processor  12 GB RAM, 256 GB inbuilt
# 1     Snapdragon 695, Octa Core, 2.2 GHz Processor   6 GB RAM, 128 GB inbuilt
# 2        Exynos 1330, Octa Core, 2.4 GHz Processor    4 GB RAM, 64 GB inbuilt
# 3    Snapdragon  695, Octa Core, 2.2 GHz Processor   6 GB RAM, 128 GB inbuilt
# ...

# %% [markdown]
# ## Data Assessing
#
# ### Quality Issues
#
# 1. **model** - some brands are written diiferently like OPPO in model column `consistency`
# 2. **price** - has unneccesary '₹' `validity`
# 3. **price** - has ',' between numbers `validity`
# 4. **price** - phone Namotel has a price of 99 `accuracy`
# 5. **ratings** - missing values `completeness`
# 6. **processor** - has some incorrect values for some samsung phones(row # -642,647,649,659,667,701,750,759,819,859,883,884,919,927,929,932,1002) `validity`
# 7. There is ipod on row 756 `validity`
# 8. **memory** - incorrect values in rows (441,485,534,553,584,610,613,642,647,649,659,667,701,750,759,819,859,884,919,927,929,932,990,1002) `validity`
# 9. **battery** - incorrect values in rows(113,151,309,365,378,441,450,553,584,610,613,630,642,647,649,659,667,701,750,756,759,764,819,855,859,884,915,916,927,929,932,990,1002) `validity`
# 10. **display** - sometimes frequency is not available `completeness`
# 11. **display** - incorrect values in rows(378,441,450,553,584,610,613,630,642,647,649,659,667,701,750,759,764,819,859,884,915,916,927,929,932,990,1002) `validity`
# 12. certain phones are foldable and the info is scattered `validity`
# 13. **camera** - words like Dual, Triple and Quad are used to represent number of cameras and front and rear cameras are separated by '&'
# 14. **camera** - problem with rows (100,113,151,157,161,238,273,308,309,323,324,365,367,378,394,441,450,484,506,534,553,571,572,575,584,610,613,615,630,642,647,649,659,667,684,687,705,711,723,728,750,756,759,764,792,819,846,854,855,858,883,884,896,915,916,927,929,932,945,956,990,995,1002,1016
# ) `validity`
# 15. **card** - sometimes contains info about os and camera `validity`
# 16. **os** - sometimes contains info about bluetooth and fm radio `validity`
# 17. **os** - issue with rows (324,378) `validity`
# 18. **os** - sometimes contains os version name like lollipop `consistency`
# 19. missing values in camera, card and os `completeness`
# 20. datatype  of price and rating is incorrect `validity`
#
#
#
# ### Tidiness Issues
#
# 1. **sim** - can be split into 3 cols has_5g, has_NFC, has_IR_Blaster
# 2. **ram** - can be split into 2 cols RAM and ROM
# 3. **processor** - can be split into processor name, cores and cpu speed.
# 4. **battery** - can be split into battery capacity, fast_charging_available
# 5. **display** - can be split into size, resolution_width, resolution_height and frequency
# 6. **camera** - can be split into front and rear camera
# 7. **card** - can be split into supported, extended_upto

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 1020 entries, 0 to 1019
# Data columns (total 11 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   model      1020 non-null   str
#  1   price      1020 non-null   str
#  2   rating     879 non-null    float64
#  3   sim        1020 non-null   str
#  4   processor  1020 non-null   str
#  5   ram        1020 non-null   str
#  6   battery    1020 non-null   str
#  7   display    1020 non-null   str
#  8   camera     1019 non-null   str
#  9   card       1013 non-null   str
#  10  os         1003 non-null   str
# dtypes: float64(1), str(10)
# memory usage: 87.8 KB

# %%
df.describe()
# Out:
#            rating
# count  879.000000
# mean    78.258248
# std      7.402854
# min     60.000000
# 25%     74.000000
# 50%     80.000000
# 75%     84.000000
# max     89.000000

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df['price'] = df['price'].str.replace('₹','').str.replace(',','')
df['price'] = df['price'].astype('int')

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 1020 entries, 0 to 1019
# Data columns (total 11 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   model      1020 non-null   str
#  1   price      1020 non-null   int64
#  2   rating     879 non-null    float64
#  3   sim        1020 non-null   str
#  4   processor  1020 non-null   str
#  5   ram        1020 non-null   str
#  6   battery    1020 non-null   str
#  7   display    1020 non-null   str
#  8   camera     1019 non-null   str
#  9   card       1013 non-null   str
#  10  os         1003 non-null   str
# dtypes: float64(1), int64(1), str(9)
# memory usage: 87.8 KB

# %%
df.head()
# Out:
#                        model  price  rating  \
# 0              OnePlus 11 5G  54999    89.0
# 1  OnePlus Nord CE 2 Lite 5G  19989    81.0
# 2      Samsung Galaxy A14 5G  16499    75.0
# 3       Motorola Moto G62 5G  14999    81.0
# 4         Realme 10 Pro Plus  24999    82.0
#
#                                        sim  \
# 0  Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 1       Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi
# 2       Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi
# 3       Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi
# 4       Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi
#
#                                          processor                        ram  \
# 0  Snapdragon 8 Gen2, Octa Core, 3.2 GHz Processor  12 GB RAM, 256 GB inbuilt
# 1     Snapdragon 695, Octa Core, 2.2 GHz Processor   6 GB RAM, 128 GB inbuilt
# 2        Exynos 1330, Octa Core, 2.4 GHz Processor    4 GB RAM, 64 GB inbuilt
# 3    Snapdragon  695, Octa Core, 2.2 GHz Processor   6 GB RAM, 128 GB inbuilt
# ...

# %%
df.reset_index(inplace=True)

# %%
df['index'] = df['index']+2

# %%
df
# Out:
#       index                            model  price  rating  \
# 0         2                    OnePlus 11 5G  54999    89.0
# 1         3        OnePlus Nord CE 2 Lite 5G  19989    81.0
# 2         4            Samsung Galaxy A14 5G  16499    75.0
# 3         5             Motorola Moto G62 5G  14999    81.0
# 4         6               Realme 10 Pro Plus  24999    82.0
# ...     ...                              ...    ...     ...
# 1015   1017       Motorola Moto Edge S30 Pro  34990    83.0
# 1016   1018                      Honor X8 5G  14990    75.0
# 1017   1019  POCO X4 GT 5G (8GB RAM + 256GB)  28990    85.0
# 1018   1020             Motorola Moto G91 5G  19990    80.0
# 1019   1021           Samsung Galaxy M52s 5G  24990    74.0
#
#                                                     sim  \
# 0               Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 1                    Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi
# 2                    Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi
# ...

# %%
processor_rows = set((642,647,649,659,667,701,750,759,819,859,883,884,919,927,929,932,1002))
memory_rows = set((441,485,534,553,584,610,613,642,647,649,659,667,701,750,759,819,859,884,919,927,929,932,990,1002))
battery_rows = set((113,151,309,365,378,441,450,553,584,610,613,630,642,647,649,659,667,701,750,756,759,764,819,855,859,884,915,916,927,929,932,990,1002))
display_rows = set((378,441,450,553,584,610,613,630,642,647,649,659,667,701,750,759,764,819,859,884,915,916,927,929,932,990,1002))
camera_rows = set((100,113,151,157,161,238,273,308,309,323,324,365,367,378,394,441,450,484,506,534,553,571,572,575,584,610,613,615,630,642,647,649,659,667,684,687,705,711,723,728,750,756,759,764,792,819,846,854,855,858,883,884,896,915,916,927,929,932,945,956,990,995,1002,1016))

# %%
# rows in which atleast one column(processor,memory,battery,display,camera) has problem
total_rows = processor_rows | memory_rows | battery_rows | display_rows | camera_rows

# %%
# rows in which all the 5 columns processor,memory,battery,display,camera has problem
common_rows = processor_rows & memory_rows & battery_rows & display_rows & camera_rows

# %%
df[df['index'].isin(total_rows)]
# Out:
#       index                              model   price  rating  \
# 98      100                     Vivo X Fold 5G  106990     NaN
# 111     113                    Apple iPhone 12   51999    74.0
# 149     151               Apple iPhone 12 Mini   40999    74.0
# 155     157                    Nokia 2780 Flip    4990     NaN
# 159     161                    Oppo Find N2 5G   94990     NaN
# ...     ...                                ...     ...     ...
# 954     956  Vivo X Fold 5G (12GB RAM + 512GB)  118990     NaN
# 988     990                Nokia 5310 Dual Sim    3399     NaN
# 993     995                      Huawei Mate X  169000     NaN
# 1000   1002                    XTouch F40 Flip    1999     NaN
# 1014   1016                      Vivo X Fold 2  119990     NaN
#
#                                                     sim  \
# 98              Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 111             Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# ...

# %%
df[df['index'].isin(common_rows)]
# Out:
#       index                   model  price  rating  \
# 640     642          Nokia 105 Plus   1299     NaN
# 645     647         Nokia 2760 Flip   5490     NaN
# 647     649       Motorola Moto A10   1339     NaN
# 657     659           Zanco Tiny T1   2799     NaN
# 665     667            itel it2163S    958     NaN
# 748     750            Nokia 400 4G   3290     NaN
# 757     759            Karbonn KU3i    995     NaN
# 817     819            itel Magic X   2239     NaN
# 882     884  Nokia 5710 XpressAudio   4799     NaN
# 925     927           Nokia 3310 4G   3999     NaN
# 927     929      Samsung Guru E1200   1685     NaN
# 930     932        iKall K88 Pro 4G   2099     NaN
# 1000   1002         XTouch F40 Flip   1999     NaN
#
#                                  sim                   processor  \
# 640                         Dual Sim      4 MB RAM, 4 MB inbuilt
# 645          Dual Sim, 3G, 4G, Wi-Fi            1450 mAh Battery
# ...

# %%
df = df[df['price']>3400]

# %%
df
# Out:
#       index                            model  price  rating  \
# 0         2                    OnePlus 11 5G  54999    89.0
# 1         3        OnePlus Nord CE 2 Lite 5G  19989    81.0
# 2         4            Samsung Galaxy A14 5G  16499    75.0
# 3         5             Motorola Moto G62 5G  14999    81.0
# 4         6               Realme 10 Pro Plus  24999    82.0
# ...     ...                              ...    ...     ...
# 1015   1017       Motorola Moto Edge S30 Pro  34990    83.0
# 1016   1018                      Honor X8 5G  14990    75.0
# 1017   1019  POCO X4 GT 5G (8GB RAM + 256GB)  28990    85.0
# 1018   1020             Motorola Moto G91 5G  19990    80.0
# 1019   1021           Samsung Galaxy M52s 5G  24990    74.0
#
#                                                     sim  \
# 0               Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 1                    Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi
# 2                    Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi
# ...

# %%
df[df['index'].isin(common_rows)]
# they all are keypad phones not smart phones
# Out:
#      index                   model  price  rating  \
# 645    647         Nokia 2760 Flip   5490     NaN
# 882    884  Nokia 5710 XpressAudio   4799     NaN
# 925    927           Nokia 3310 4G   3999     NaN
#
#                                 sim                   processor  \
# 645         Dual Sim, 3G, 4G, Wi-Fi            1450 mAh Battery
# 882                Dual Sim, 3G, 4G                     No Wifi
# 925  Dual Sim, 3G, 4G, VoLTE, Wi-Fi  256 MB RAM, 512 MB inbuilt
#
#                                   ram                           battery  \
# 645  3.6 inches, 240 x 320 px Display     5 MP Rear & 5 MP Front Camera
# 882                       Unisoc T107         48 MB RAM, 128 MB inbuilt
# 925                  1200 mAh Battery  2.4 inches, 240 x 320 px Display
#
#                                display                             camera  \
# 645  Memory Card Supported, upto 32 GB                         Kaios v3.0
# ...

# %%
df = df[~df['index'].isin(common_rows)]

# %%
df.shape[0]
# Out:
# 988

# %%
# Now work on processor wala column
df[df['index'].isin(processor_rows)]
# Out:
#      index        model  price  rating                        sim  \
# 857    859  LG Folder 2  11999     NaN  Single Sim, 3G, 4G, Wi-Fi
#
#                   processor               ram  \
# 857  1 GB RAM, 8 GB inbuilt  1470 mAh Battery
#
#                               battery           display  \
# 857  2.8 inches, 240 x 320 px Display  2 MP Rear Camera
#
#                     camera       card   os
# 857  Memory Card Supported  Bluetooth  NaN

# %%
df = df[~df['index'].isin(processor_rows)]
df.shape[0]
# Out:
# 987

# %%
# # Now work on ram  wala column
df[df['index'].isin(memory_rows)]
# Out:
#      index                             model   price  rating  \
# 439    441            Apple iPhone SE 3 2022   43900     NaN
# 483    485  Huawei Mate 50 RS Porsche Design  239999    81.0
# 582    584                     Nokia 8210 4G    3749     NaN
#
#                                                  sim  \
# 439          Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 483  Dual Sim, 3G, 4G, VoLTE, Wi-Fi, NFC, IR Blaster
# 582                                 Dual Sim, 3G, 4G
#
#                                             processor             ram  \
# 439        Bionic  A15, Hexa Core, 3.22 GHz Processor   64 GB inbuilt
# 483  Snapdragon 8+ Gen1, Octa Core, 3.2 GHz Processor  512 GB inbuilt
# 582                                           No Wifi     Unisoc T107
#
#                                      battery  \
# 439        4.7 inches, 750 x 1334 px Display
# 483  4700 mAh Battery with 66W Fast Charging
# 582                48 MB RAM, 128 MB inbuilt
#
# ...

# %%
df.drop(582,inplace=True)

# %%
df[df['index'].isin(memory_rows)]
# Out:
#      index                             model   price  rating  \
# 439    441            Apple iPhone SE 3 2022   43900     NaN
# 483    485  Huawei Mate 50 RS Porsche Design  239999    81.0
#
#                                                  sim  \
# 439          Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 483  Dual Sim, 3G, 4G, VoLTE, Wi-Fi, NFC, IR Blaster
#
#                                             processor             ram  \
# 439        Bionic  A15, Hexa Core, 3.22 GHz Processor   64 GB inbuilt
# 483  Snapdragon 8+ Gen1, Octa Core, 3.2 GHz Processor  512 GB inbuilt
#
#                                      battery  \
# 439        4.7 inches, 750 x 1334 px Display
# 483  4700 mAh Battery with 66W Fast Charging
#
#                                          display  \
# 439               12 MP Rear & 7 MP Front Camera
# 483  6.74 inches, 1212 x 2616 px, 120 Hz Display
#
#                                                 camera  \
# ...

# %%
# Now work on ram  wala column
df[df['index'].isin(battery_rows)]
# Out:
#      index                         model   price  rating  \
# 111    113               Apple iPhone 12   51999    74.0
# 149    151          Apple iPhone 12 Mini   40999    74.0
# 307    309       Apple iPhone 12 (128GB)   55999    75.0
# 363    365  Apple iPhone 12 Mini (128GB)   45999    75.0
# 376    378               Nokia 2660 Flip    4649     NaN
# 439    441        Apple iPhone SE 3 2022   43900     NaN
# 448    450           Apple iPhone 15 Pro  130990    75.0
# 628    630   Apple iPhone 12 Pro (512GB)  139900    80.0
# 754    756    Apple iPod Touch (7th Gen)   18900     NaN
# 762    764             Apple iPhone SE 4   49990    60.0
# 853    855   Apple iPhone 12 Pro (256GB)  119900    80.0
# 913    915  Apple iPhone 12 Mini (256GB)   55999    75.0
# 914    916       Apple iPhone 12 (256GB)   67999    76.0
#
#                                          sim  \
# 111  Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 149  Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# ...

# %%
df.drop([376,754],inplace=True)

# %%
df[df['index'].isin(battery_rows)]
# Out:
#      index                         model   price  rating  \
# 111    113               Apple iPhone 12   51999    74.0
# 149    151          Apple iPhone 12 Mini   40999    74.0
# 307    309       Apple iPhone 12 (128GB)   55999    75.0
# 363    365  Apple iPhone 12 Mini (128GB)   45999    75.0
# 439    441        Apple iPhone SE 3 2022   43900     NaN
# 448    450           Apple iPhone 15 Pro  130990    75.0
# 628    630   Apple iPhone 12 Pro (512GB)  139900    80.0
# 762    764             Apple iPhone SE 4   49990    60.0
# 853    855   Apple iPhone 12 Pro (256GB)  119900    80.0
# 913    915  Apple iPhone 12 Mini (256GB)   55999    75.0
# 914    916       Apple iPhone 12 (256GB)   67999    76.0
#
#                                          sim  \
# 111  Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 149  Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 307  Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 363  Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 439  Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# ...

# %%
temp_df = df[df['index'].isin(battery_rows)]

# %%
x = temp_df.iloc[:,7:].shift(1,axis=1).values
x
# Out:
# array([[nan,
#         '6.1 inches, 1170\u2009x\u20092532\u2009px Display with Large Notch',
#         '12\u2009MP + 12\u2009MP Dual Rear & 12\u2009MP Front Camera',
#         'Memory Card Not Supported', 'iOS v14'],
#        [nan, '5.4 inches, 1080\u2009x\u20092340\u2009px Display',
#         '12\u2009MP + 12\u2009MP Dual Rear & 12\u2009MP Front Camera',
#         'Memory Card Not Supported', 'iOS v14'],
#        [nan,
#         '6.1 inches, 1170\u2009x\u20092532\u2009px Display with Large Notch',
#         '12\u2009MP + 12\u2009MP Dual Rear & 12\u2009MP Front Camera',
#         'Memory Card Not Supported', 'iOS v14'],
#        [nan, '5.4 inches, 1080\u2009x\u20092340\u2009px Display',
#         '12\u2009MP + 12\u2009MP Dual Rear & 12\u2009MP Front Camera',
#         'Memory Card Not Supported', 'iOS v14'],
#        [nan, '4.7 inches, 750\u2009x\u20091334\u2009px Display',
#         '12\u2009MP Rear & 7\u2009MP Front Camera',
#         'Memory Card Not Supported', 'iOS v15'],
# ...

# %%
df.loc[temp_df.index,temp_df.columns[7:]] = x

# %%
df[df['index'].isin(battery_rows)]
# Out:
#      index                         model   price  rating  \
# 111    113               Apple iPhone 12   51999    74.0
# 149    151          Apple iPhone 12 Mini   40999    74.0
# 307    309       Apple iPhone 12 (128GB)   55999    75.0
# 363    365  Apple iPhone 12 Mini (128GB)   45999    75.0
# 439    441        Apple iPhone SE 3 2022   43900     NaN
# 448    450           Apple iPhone 15 Pro  130990    75.0
# 628    630   Apple iPhone 12 Pro (512GB)  139900    80.0
# 762    764             Apple iPhone SE 4   49990    60.0
# 853    855   Apple iPhone 12 Pro (256GB)  119900    80.0
# 913    915  Apple iPhone 12 Mini (256GB)   55999    75.0
# 914    916       Apple iPhone 12 (256GB)   67999    76.0
#
#                                          sim  \
# 111  Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 149  Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 307  Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 363  Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 439  Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# ...

# %%
# Now work on display wala column
df[df['index'].isin(display_rows)]
# Out:
#      index                         model   price  rating  \
# 439    441        Apple iPhone SE 3 2022   43900     NaN
# 448    450           Apple iPhone 15 Pro  130990    75.0
# 628    630   Apple iPhone 12 Pro (512GB)  139900    80.0
# 762    764             Apple iPhone SE 4   49990    60.0
# 913    915  Apple iPhone 12 Mini (256GB)   55999    75.0
# 914    916       Apple iPhone 12 (256GB)   67999    76.0
#
#                                          sim  \
# 439  Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 448  Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 628  Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 762  Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 913  Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 914  Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
#
#                                       processor                       ram  \
# 439  Bionic  A15, Hexa Core, 3.22 GHz Processor             64 GB inbuilt
# 448                                 Bionic  A16  8 GB RAM, 128 GB inbuilt
# ...

# %%
# Now work on display wala column
df[df['index'].isin(camera_rows)]
# Out:
#       index                                     model   price  rating  \
# 98      100                            Vivo X Fold 5G  106990     NaN
# 111     113                           Apple iPhone 12   51999    74.0
# 149     151                      Apple iPhone 12 Mini   40999    74.0
# 155     157                           Nokia 2780 Flip    4990     NaN
# 159     161                           Oppo Find N2 5G   94990     NaN
# 236     238                      Xiaomi Mix Fold 2 5G  106990     NaN
# 271     273                         Nokia 2720 V Flip    6199     NaN
# 306     308                   Samsung Galaxy Z Flip 3   69999    84.0
# 307     309                   Apple iPhone 12 (128GB)   55999    75.0
# 321     323                   Samsung Galaxy Z Fold 4  154998     NaN
# 322     324                          Royole FlexPai 2  109999    87.0
# 363     365              Apple iPhone 12 Mini (128GB)   45999    75.0
# ...

# %%
df.drop([155,271,844],inplace=True)
# 155 271 844

# %%
df[df['index'].isin(camera_rows)]
# Out:
#       index                                     model   price  rating  \
# 98      100                            Vivo X Fold 5G  106990     NaN
# 111     113                           Apple iPhone 12   51999    74.0
# 149     151                      Apple iPhone 12 Mini   40999    74.0
# 159     161                           Oppo Find N2 5G   94990     NaN
# 236     238                      Xiaomi Mix Fold 2 5G  106990     NaN
# 306     308                   Samsung Galaxy Z Flip 3   69999    84.0
# 307     309                   Apple iPhone 12 (128GB)   55999    75.0
# 321     323                   Samsung Galaxy Z Fold 4  154998     NaN
# 322     324                          Royole FlexPai 2  109999    87.0
# 363     365              Apple iPhone 12 Mini (128GB)   45999    75.0
# 365     367                          OPPO Find N Flip   89990    88.0
# 392     394                         OPPO Find N2 Flip   70990    88.0
# ...

# %%
temp_df = df[df['index'].isin(camera_rows)]

# %%
temp_df = temp_df[~temp_df['camera'].str.contains('MP')]
temp_df
# Out:
#       index                                     model   price  rating  \
# 98      100                            Vivo X Fold 5G  106990     NaN
# 159     161                           Oppo Find N2 5G   94990     NaN
# 236     238                      Xiaomi Mix Fold 2 5G  106990     NaN
# 306     308                   Samsung Galaxy Z Flip 3   69999    84.0
# 321     323                   Samsung Galaxy Z Fold 4  154998     NaN
# 322     324                          Royole FlexPai 2  109999    87.0
# 365     367                          OPPO Find N Flip   89990    88.0
# 392     394                         OPPO Find N2 Flip   70990    88.0
# 482     484                          Vivo X Fold Plus  113990     NaN
# 504     506                Samsung Galaxy Z Flip 4 5G   89999    88.0
# 569     571                   Samsung Galaxy Z Fold 3  110999    89.0
# 570     572                                LG Wing 5G   54999    89.0
# ...

# %%
df.loc[temp_df.index,'camera'] = temp_df['card'].values

# %%
df[df['index'].isin(camera_rows)]
# Out:
#       index                                     model   price  rating  \
# 98      100                            Vivo X Fold 5G  106990     NaN
# 111     113                           Apple iPhone 12   51999    74.0
# 149     151                      Apple iPhone 12 Mini   40999    74.0
# 159     161                           Oppo Find N2 5G   94990     NaN
# 236     238                      Xiaomi Mix Fold 2 5G  106990     NaN
# 306     308                   Samsung Galaxy Z Flip 3   69999    84.0
# 307     309                   Apple iPhone 12 (128GB)   55999    75.0
# 321     323                   Samsung Galaxy Z Fold 4  154998     NaN
# 322     324                          Royole FlexPai 2  109999    87.0
# 363     365              Apple iPhone 12 Mini (128GB)   45999    75.0
# 365     367                          OPPO Find N Flip   89990    88.0
# 392     394                         OPPO Find N2 Flip   70990    88.0
# ...

# %%
# now work with card column
df['card'].value_counts()
# Out:
# card
# Memory Card Supported, upto 1 TB                                       171
# Memory Card Not Supported                                              123
# Android v12                                                            107
# Memory Card Supported, upto 512 GB                                     105
# Memory Card (Hybrid), upto 1 TB                                         91
# Memory Card Supported                                                   89
# Memory Card Supported, upto 256 GB                                      87
# Android v13                                                             46
# Android v11                                                             41
# Memory Card (Hybrid)                                                    30
# Memory Card (Hybrid), upto 256 GB                                       13
# Memory Card (Hybrid), upto 512 GB                                       11
# ...

# %%
# differnacing factort is Memory Card word

# %%
temp_df = df[df['card'].str.contains('MP')]
temp_df
# Out:
#       index                                     model   price  rating  \
# 69       71                          Oppo Find N Fold   99990     NaN
# 98      100                            Vivo X Fold 5G  106990     NaN
# 159     161                           Oppo Find N2 5G   94990     NaN
# 236     238                      Xiaomi Mix Fold 2 5G  106990     NaN
# 306     308                   Samsung Galaxy Z Flip 3   69999    84.0
# 321     323                   Samsung Galaxy Z Fold 4  154998     NaN
# 322     324                          Royole FlexPai 2  109999    87.0
# 365     367                          OPPO Find N Flip   89990    88.0
# 392     394                         OPPO Find N2 Flip   70990    88.0
# 482     484                          Vivo X Fold Plus  113990     NaN
# 504     506                Samsung Galaxy Z Flip 4 5G   89999    88.0
# 569     571                   Samsung Galaxy Z Fold 3  110999    89.0
# ...

# %%
df.loc[temp_df.index,'card'] = 'Memory Card Not Supported'

# %%
df[df['card'].str.contains('MP')]
# Out:
# Empty DataFrame
# Columns: [index, model, price, rating, sim, processor, ram, battery, display, camera, card, os]
# Index: []

# %%
df['card'].value_counts()
# Out:
# card
# Memory Card Supported, upto 1 TB       171
# Memory Card Not Supported              148
# Android v12                            107
# Memory Card Supported, upto 512 GB     105
# Memory Card (Hybrid), upto 1 TB         91
# Memory Card Supported                   89
# Memory Card Supported, upto 256 GB      87
# Android v13                             46
# Android v11                             41
# Memory Card (Hybrid)                    30
# Memory Card (Hybrid), upto 256 GB       13
# Memory Card (Hybrid), upto 512 GB       11
# Android v10                             11
# Memory Card Supported, upto 128 GB       6
# Memory Card Supported, upto 2 TB         5
# Memory Card Supported, upto 32 GB        4
# Memory Card (Hybrid), upto 128 GB        3
# Memory Card (Hybrid), upto 64 GB         3
# Android v9.0 (Pie)                       2
# Android v12.1                            1
# Memory Card Supported, upto 1000 GB      1
# iOS v10                                  1
# ...

# %%
pd.set_option('display.max_rows',None)
temp_df = df[~df['card'].str.contains('Memory Card')]
temp_df
# Out:
#       index                                           model   price  rating  \
# 8        10                                 Nothing Phone 1   26749    85.0
# 9        11                              OnePlus Nord 2T 5G   28999    84.0
# 12       14                     Xiaomi Redmi Note 12 Pro 5G   24762    79.0
# 17       19                            OPPO Reno 9 Pro Plus   45999    86.0
# 18       20                                  OnePlus 10R 5G   32999    86.0
# 20       22                                     OnePlus 11R   39999    85.0
# 21       23                                 Vivo V25 Pro 5G   35999    85.0
# 24       26                                    Vivo V26 Pro   42990    87.0
# 29       31                                  OnePlus 11 Pro   69999     NaN
# 37       39                     Samsung Galaxy S22 Ultra 5G   91999     NaN
# 39       41                                  OPPO Reno 9 5G   28499    83.0
# ...

# %%
df.loc[temp_df.index,'os'] = temp_df['card'].values

# %%
df.loc[temp_df.index,'card'] = 'Memory Card Not Supported'

# %%
df['card'].value_counts()
# Out:
# card
# Memory Card Not Supported              361
# Memory Card Supported, upto 1 TB       171
# Memory Card Supported, upto 512 GB     105
# Memory Card (Hybrid), upto 1 TB         91
# Memory Card Supported                   89
# Memory Card Supported, upto 256 GB      87
# Memory Card (Hybrid)                    30
# Memory Card (Hybrid), upto 256 GB       13
# Memory Card (Hybrid), upto 512 GB       11
# Memory Card Supported, upto 128 GB       6
# Memory Card Supported, upto 2 TB         5
# Memory Card Supported, upto 32 GB        4
# Memory Card (Hybrid), upto 128 GB        3
# Memory Card (Hybrid), upto 64 GB         3
# Memory Card Supported, upto 1000 GB      1
# Memory Card (Hybrid), upto 2 TB          1
# Name: count, dtype: int64

# %%
df['os'].value_counts()
# Out:
# os
# Android v12                           394
# Android v11                           274
# Android v13                            91
# Android v10                            69
# Android v9.0 (Pie)                     29
# Android v10.0                          23
# iOS v16                                15
# iOS v15                                12
# Android v8.1 (Oreo)                    10
# iOS v14                                 6
# Memory Card Not Supported               6
# iOS v13                                 4
# Android v11.0                           4
# Android v8.0 (Oreo)                     4
# iOS v15.0                               3
# Android v12.1                           2
# Memory Card Supported, upto 256 GB      2
# Android v5.1.1 (Lollipop)               2
# Memory Card (Hybrid), upto 2 TB         2
# iOS v14.0                               2
# Harmony v2.0                            2
# Memory Card (Hybrid), upto 256 GB       2
# ...

# %%
temp_df = df[df['os'].str.contains('Memory Card')]
temp_df
# Out:
#      index                       model   price  rating  \
# 159    161             Oppo Find N2 5G   94990     NaN
# 306    308     Samsung Galaxy Z Flip 3   69999    84.0
# 322    324            Royole FlexPai 2  109999    87.0
# 365    367            OPPO Find N Flip   89990    88.0
# 392    394           OPPO Find N2 Flip   70990    88.0
# 504    506  Samsung Galaxy Z Flip 4 5G   89999    88.0
# 570    572                  LG Wing 5G   54999    89.0
# 613    615                Oukitel WP21   22990    82.0
# 682    684                LG V60 ThinQ   79990     NaN
# 721    723  Asus ROG Phone 6D Ultimate  107990     NaN
# 726    728            Huawei Mate Xs 2  162990    89.0
# 894    896         Royole FlexPai 3 5G  149999    87.0
# 993    995               Huawei Mate X  169000     NaN
#
#                                                    sim  \
# 159            Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 306          Single Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# ...

# %%
temp_df = temp_df[temp_df['os'].str.contains('B')]
temp_df
# Out:
#      index                model   price  rating  \
# 322    324     Royole FlexPai 2  109999    87.0
# 570    572           LG Wing 5G   54999    89.0
# 682    684         LG V60 ThinQ   79990     NaN
# 726    728     Huawei Mate Xs 2  162990    89.0
# 894    896  Royole FlexPai 3 5G  149999    87.0
# 993    995        Huawei Mate X  169000     NaN
#
#                                                    sim  \
# 322                 Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi
# 570            Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 682            Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 726    Dual Sim, 3G, 4G, VoLTE, Wi-Fi, NFC, IR Blaster
# 894                 Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi
# 993  Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC, IR Bl...
#
#                                            processor  \
# 322    Snapdragon 865, Octa Core, 2.84 GHz Processor
# 570  Snapdragon  765G , Octa Core, 2.4 GHz Processor
# 682   Snapdragon  865, Octa Core, 2.84 GHz Processor
# ...

# %%
df.loc[temp_df.index,'card'] = temp_df['os'].values

# %%
temp_df = df[df['os'].str.contains('Memory Card')]
temp_df
# Out:
#      index                       model   price  rating  \
# 159    161             Oppo Find N2 5G   94990     NaN
# 306    308     Samsung Galaxy Z Flip 3   69999    84.0
# 322    324            Royole FlexPai 2  109999    87.0
# 365    367            OPPO Find N Flip   89990    88.0
# 392    394           OPPO Find N2 Flip   70990    88.0
# 504    506  Samsung Galaxy Z Flip 4 5G   89999    88.0
# 570    572                  LG Wing 5G   54999    89.0
# 613    615                Oukitel WP21   22990    82.0
# 682    684                LG V60 ThinQ   79990     NaN
# 721    723  Asus ROG Phone 6D Ultimate  107990     NaN
# 726    728            Huawei Mate Xs 2  162990    89.0
# 894    896         Royole FlexPai 3 5G  149999    87.0
# 993    995               Huawei Mate X  169000     NaN
#
#                                                    sim  \
# 159            Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 306          Single Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# ...

# %%
df.loc[temp_df.index,'os'] = np.nan

# %%
temp_df = df[df['os'].str.contains('Bluetooth')]
df.loc[temp_df.index,'os'] = np.nan

# %%
df['os'].value_counts()
# Out:
# os
# Android v12                        394
# Android v11                        274
# Android v13                         91
# Android v10                         69
# Android v9.0 (Pie)                  29
# Android v10.0                       23
# iOS v16                             15
# iOS v15                             12
# Android v8.1 (Oreo)                 10
# iOS v14                              6
# iOS v13                              4
# Android v11.0                        4
# Android v8.0 (Oreo)                  4
# iOS v15.0                            3
# Android v12.1                        2
# Android v5.1.1 (Lollipop)            2
# iOS v14.0                            2
# Harmony v2.0                         2
# HarmonyOS v2.0                       2
# Android v6.0 (Marshmallow)           2
# EMUI v12                             2
# HarmonyOS v2                         1
# iOS v13.0                            1
# iOS v12.3                            1
# ...

# %%
brand_names = df['model'].str.split(' ').str.get(0)
brand_names
# Out:
# 0         OnePlus
# 1         OnePlus
# 2         Samsung
# 3        Motorola
# 4          Realme
# 5         Samsung
# 6           Apple
# 7          Xiaomi
# 8         Nothing
# 9         OnePlus
# 10         Realme
# 11           Oppo
# 12         Xiaomi
# 13           Vivo
# 14        Samsung
# 15          Apple
# 16           Vivo
# 17           OPPO
# 18        OnePlus
# 19           Vivo
# 20        OnePlus
# 21           Vivo
# 22           Poco
# 23         Xiaomi
# 24           Vivo
# 25        Samsung
# 26        OnePlus
# 27          Apple
# 28           Vivo
# 29        OnePlus
# 30         Realme
# 31           Poco
# 32           Vivo
# 33          Apple
# 34        Samsung
# 35        Samsung
# 36           Oppo
# 37        Samsung
# 38         Xiaomi
# 39           OPPO
# 40        OnePlus
# 41         Xiaomi
# 42       Motorola
# 43         Realme
# 44           Vivo
# 45        Samsung
# 46         Xiaomi
# 47         Realme
# 48           Vivo
# 49        Samsung
# ...

# %%
pd.reset_option('display.max_rows')
df.insert(1,'brand_name',brand_names)

# %%
df['brand_name'] = df['brand_name'].str.lower()

# %%
simtype = df['sim'].str.split(',').str.get(0)
df.insert(6,'sim_type',simtype)

# %%
has_3g = df['sim'].str.contains('3G')
df.insert(7,'has_3G',has_3g)

has_4g = df['sim'].str.contains('4G')
df.insert(8,'has_4G',has_4g)

has_5g = df['sim'].str.contains('5G')
df.insert(9,'has_5G',has_5g)

has_nfc = df['sim'].str.contains('NFC')
df.insert(10,'has_nfc',has_nfc)

has_irblaster = df['sim'].str.contains('IR Blaster')
df.insert(11,'has_irblaster',has_irblaster)

# %%
processor_name = df['processor'].str.split(',').str.get(0)
df.insert(13,'processor_name',processor_name)

num_cores = df['processor'].str.split(',').str.get(1)
df.insert(14,'num_cores',num_cores)

# %%
processor_speed = df['processor'].str.split(',').str.get(2)
df.insert(15,'processor_speed',processor_speed)

# %%
# pd.set_option('display.max_rows',None)
pd.set_option('display.max_columns',None)
# pd.reset_option('display.max_rows')
# pd.reset_option('display.max_columns')
# df

# %%
# acuuracy error snapdragon ki jgah ek row me sanpdragon tha
temp_df = df[df['processor_name']=='Sanpdragon']
df.loc[temp_df.index,'processor_type'] = 'Snapdragon 680'

# %%
# processor_type has validation issue means has coretype values
temp_df = df[df['processor_name'].str.contains('Core')]
temp_df
# Out:
#       index brand_name                                 model  price  rating  \
# 118     120      tesla                        Tesla Pi Phone  69999    83.0
# 143     145        jio                           Jio Phone 3   4499     NaN
# 188     190      ikall                         iKall Z19 Pro   8099    60.0
# 201     203    samsung                    Samsung Galaxy A13  14450    75.0
# 309     311    samsung  Samsung Galaxy A13 (4GB RAM + 128GB)  14999    75.0
# 315     317       itel                          itel S16 Pro   6990     NaN
# 496     498    samsung                    Samsung Galaxy A15  15990    63.0
# 529     531    samsung                    Samsung Galaxy F14  14990    67.0
# 587     589    samsung  Samsung Galaxy A13 (6GB RAM + 128GB)  16499    78.0
# 758     760      ikall                             iKall Z19   7999    61.0
# 778     780      tecno                   Tecno Spark Go 2022   6249    61.0
# ...

# %%
x = temp_df.iloc[:,13:16].shift(1,axis=1).values
x
# Out:
# array([[None, 'Octa Core Processor', nan],
#        [None, 'Quad Core', ' 1.4\u2009GHz Processor'],
#        [None, 'Quad Core', ' 1.6\u2009GHz Processor'],
#        [None, 'Octa Core', ' 2\u2009GHz Processor'],
#        [None, 'Octa Core', ' 2\u2009GHz Processor'],
#        [None, 'Quad Core', ' 1.3\u2009GHz Processor'],
#        [None, 'Octa Core Processor', nan],
#        [None, 'Octa Core Processor', nan],
#        [None, 'Octa Core', ' 2\u2009GHz Processor'],
#        [None, 'Quad Core', ' 1.6\u2009GHz Processor'],
#        [None, 'Octa Core', ' 2.2\u2009GHz Processor'],
#        [None, 'Quad Core', ' 1.3\u2009GHz Processor'],
#        [None, 'Octa Core Processor', nan],
#        [None, 'Octa Core Processor', nan],
#        [None, 'Octa Core Processor', nan],
#        [None, 'Octa Core Processor', nan],
#        [None, 'Octa Core Processor', nan],
#        [None, 'Octa Core', ' 1.8\u2009GHz Processor'],
#        [None, 'Quad Core', ' 1.3\u2009GHz Processor'],
# ...

# %%
df.loc[temp_df.index,temp_df.columns[13:16]] = x

# %%
df[df['processor_name'].str.contains('Core',na=False)]
# Out:
# Empty DataFrame
# Columns: [index, brand_name, model, price, rating, sim, sim_type, has_3G, has_4G, has_5G, has_nfc, has_irblaster, processor, processor_name, num_cores, processor_speed, ram, battery, display, camera, card, os, processor_type]
# Index: []

# %%
#change processor type (2 nm) to Mediatek MT6739
df[df['processor_name'] == '(28 nm)']
# Out:
#      index brand_name                    model  price  rating  \
# 856    858    samsung  Samsung Galaxy A01 Core   4999     NaN
#
#                                 sim  sim_type  has_3G  has_4G  has_5G  \
# 856  Dual Sim, 3G, 4G, VoLTE, Wi-Fi  Dual Sim    True    True   False
#
#      has_nfc  has_irblaster                              processor  \
# 856    False          False  (28 nm), Quad Core, 1.5 GHz Processor
#
#     processor_name   num_cores     processor_speed                      ram  \
# 856        (28 nm)   Quad Core   1.5 GHz Processor  1 GB RAM, 16 GB inbuilt
#
#               battery                            display  \
# 856  3000 mAh Battery  5.3 inches, 720 x 1480 px Display
#
#                             camera                   card           os  \
# 856  8 MP Rear & 5 MP Front Camera  Memory Card Supported  Android v10
#
#     processor_type
# 856            NaN

# %%
df.loc[856, 'processor_name'] = 'Mediatek MT6739'

# %%
df.loc[856]
# Out:
# index                                                858
# brand_name                                       samsung
# model                            Samsung Galaxy A01 Core
# price                                               4999
# rating                                               NaN
# sim                       Dual Sim, 3G, 4G, VoLTE, Wi-Fi
# sim_type                                        Dual Sim
# has_3G                                              True
# has_4G                                              True
# has_5G                                             False
# has_nfc                                            False
# has_irblaster                                      False
# processor          (28 nm), Quad Core, 1.5 GHz Processor
# processor_name                           Mediatek MT6739
# num_cores                                      Quad Core
# processor_speed                        1.5 GHz Processor
# ...

# %%
# add new col name processor_brand 
processor_brand = df['processor'].str.split(',').str.get(0).str.split(' ').str.get(0)
df.insert(14,'processor_brand',processor_brand)

# %%
df.head(1)
# Out:
#    index brand_name          model  price  rating  \
# 0      2    oneplus  OnePlus 11 5G  54999    89.0
#
#                                        sim  sim_type  has_3G  has_4G  has_5G  \
# 0  Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC  Dual Sim    True    True    True
#
#    has_nfc  has_irblaster                                        processor  \
# 0     True          False  Snapdragon 8 Gen2, Octa Core, 3.2 GHz Processor
#
#       processor_name processor_brand   num_cores     processor_speed  \
# 0  Snapdragon 8 Gen2      Snapdragon   Octa Core   3.2 GHz Processor
#
#                          ram                                   battery  \
# 0  12 GB RAM, 256 GB inbuilt  5000 mAh Battery with 100W Fast Charging
#
#                                              display  \
# 0  6.7 inches, 1440 x 3216 px, 120 Hz Display wit...
#
#                                               camera  \
# 0  50 MP + 48 MP + 32 MP Triple Rear & 16 MP Fron...
#
# ...

# %%
df['num_cores'] = df['num_cores'].str.strip()

# %%
df['num_cores'] = df['num_cores'].str.replace('Octa Core Processor','Octa Core')
df['num_cores'] = df['num_cores'].str.replace('Hexa Core Processor','Hexa Core')

# %%
df['num_cores'].value_counts()
# Out:
# num_cores
# Octa Core    899
# Hexa Core     39
# Quad Core     36
# Name: count, dtype: int64

# %%
df['processor_speed'] = df['processor_speed'].str.strip().str.replace('GHz Processor','')

# %%
df['processor_speed'] = df['processor_speed'].astype('float')

# %%
# now work with processor speed
df['processor_speed'].value_counts()
# Out:
# processor_speed
# 2.00    146
# 2.20    135
# 2.40    128
# 3.20     94
# 2.30     86
# 3.00     53
# 2.84     36
# 2.05     28
# 2.50     23
# 1.80     23
# 1.60     20
# 2.85     19
# 3.22     18
# 3.10     15
# 2.60     14
# 2.90     13
# 1.82     10
# 2.80      9
# 1.30      9
# 2.73      9
# 2.36      8
# 3.05      8
# 2.65      5
# 1.40      5
# 2.70      5
# 1.50      4
# 2.96      3
# 2.86      3
# 3.13      2
# 1.10      1
# 2.35      1
# 2.37      1
# 1.99      1
# 1.95      1
# 2.10      1
# 1.20      1
# Name: count, dtype: int64

# %%
# Now work with Ram col
ram_cap = df['ram'].str.extract(r'(\d+)').astype('Int64')
# ram_cap.astype('Float64')

# %%
df.insert(18,'ram_capacity',ram_cap)

# %%
internal_memory = df['ram'].str.split(',').str.get(1)
df.insert(19,'internal_memory',internal_memory)

# %%
df.head(1)
# Out:
#    index brand_name          model  price  rating  \
# 0      2    oneplus  OnePlus 11 5G  54999    89.0
#
#                                        sim  sim_type  has_3G  has_4G  has_5G  \
# 0  Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC  Dual Sim    True    True    True
#
#    has_nfc  has_irblaster                                        processor  \
# 0     True          False  Snapdragon 8 Gen2, Octa Core, 3.2 GHz Processor
#
#       processor_name processor_brand  num_cores  processor_speed  \
# 0  Snapdragon 8 Gen2      Snapdragon  Octa Core              3.2
#
#                          ram  ram_capacity  internal_memory  \
# 0  12 GB RAM, 256 GB inbuilt            12   256 GB inbuilt
#
#                                     battery  \
# 0  5000 mAh Battery with 100W Fast Charging
#
#                                              display  \
# 0  6.7 inches, 1440 x 3216 px, 120 Hz Display wit...
#
#                                               camera  \
# ...

# %%
temp_df = df[df['internal_memory'].str.contains('TB',na=False)]
temp_df
# Out:
#      index brand_name                                     model   price  \
# 290    292      apple             Apple iPhone 14 Pro Max (1TB)  182999
# 781    783      apple             Apple iPhone 13 Pro Max (1TB)  179900
# 814    816      apple                 Apple iPhone 14 Pro (1TB)  172999
# 943    945    samsung  Samsung Galaxy Z Fold 4 (12GB RAM + 1TB)  163980
# 961    963      apple                 Apple iPhone 13 Pro (1TB)  147900
#
#      rating                                      sim  sim_type  has_3G  \
# 290    78.0  Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC  Dual Sim    True
# 781    86.0  Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC  Dual Sim    True
# 814    77.0  Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC  Dual Sim    True
# 943     NaN  Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC  Dual Sim    True
# 961    84.0  Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC  Dual Sim    True
#
#      has_4G  has_5G  has_nfc  has_irblaster  \
# 290    True    True     True          False
# ...

# %%
df.loc[temp_df.index,'internal_memory'] = '1000\u2009GB inbuilt'

# %%
df['internal_memory'] = df['internal_memory'].str.strip().str.extract(r'(\d+)').astype('Int64')

# %%
~df['ram'].str.contains('MB')
# Out:
# 0       True
# 1       True
# 2       True
# 3       True
# 4       True
#         ...
# 1015    True
# 1016    True
# 1017    True
# 1018    True
# 1019    True
# Name: ram, Length: 981, dtype: bool

# %%
df[df['ram'].str.contains('MB')]
# Out:
#      index brand_name          model  price  rating                      sim  \
# 486    488      nokia  Nokia 8000 4G   6899     NaN  Dual Sim, 3G, 4G, Wi-Fi
# 627    629      nokia   Nokia 225 4G   3589     NaN  Dual Sim, 3G, 4G, VoLTE
#
#      sim_type  has_3G  has_4G  has_5G  has_nfc  has_irblaster  \
# 486  Dual Sim    True    True   False    False          False
# 627  Dual Sim    True    True   False    False          False
#
#                                          processor   processor_name  \
# 486  Snapdragon  210, Quad Core, 1.1 GHz Processor  Snapdragon  210
# 627                                    Unisoc T117      Unisoc T117
#
#     processor_brand  num_cores  processor_speed                        ram  \
# 486      Snapdragon  Quad Core              1.1   512 MB RAM, 4 GB inbuilt
# 627          Unisoc        NaN              NaN  64 MB RAM, 128 MB inbuilt
#
#      ram_capacity  internal_memory           battery  \
# ...

# %%
# they are feature phones
df.drop([486,627],inplace=True)

# %%
temp_df = df[(df['ram_capacity']>18)]
temp_df
# Out:
#      index brand_name                             model   price  rating  \
# 439    441      apple            Apple iPhone SE 3 2022   43900     NaN
# 483    485     huawei  Huawei Mate 50 RS Porsche Design  239999    81.0
# 762    764      apple                 Apple iPhone SE 4   49990    60.0
#
#                                                  sim  sim_type  has_3G  \
# 439          Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC  Dual Sim    True
# 483  Dual Sim, 3G, 4G, VoLTE, Wi-Fi, NFC, IR Blaster  Dual Sim    True
# 762          Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC  Dual Sim    True
#
#      has_4G  has_5G  has_nfc  has_irblaster  \
# 439    True    True     True          False
# 483    True   False     True           True
# 762    True    True     True          False
#
#                                             processor      processor_name  \
# 439        Bionic  A15, Hexa Core, 3.22 GHz Processor         Bionic  A15
# ...

# %%
x = temp_df.loc[:,['ram_capacity','internal_memory']].shift(1,axis=1).values
x
# Out:
# array([[<NA>, 64],
#        [<NA>, 512],
#        [<NA>, 64]], dtype=object)

# %%
df.loc[temp_df.index,['ram_capacity','internal_memory']] = x

# %%
df.loc[[439,483,762]]
# Out:
#      index brand_name                             model   price  rating  \
# 439    441      apple            Apple iPhone SE 3 2022   43900     NaN
# 483    485     huawei  Huawei Mate 50 RS Porsche Design  239999    81.0
# 762    764      apple                 Apple iPhone SE 4   49990    60.0
#
#                                                  sim  sim_type  has_3G  \
# 439          Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC  Dual Sim    True
# 483  Dual Sim, 3G, 4G, VoLTE, Wi-Fi, NFC, IR Blaster  Dual Sim    True
# 762          Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC  Dual Sim    True
#
#      has_4G  has_5G  has_nfc  has_irblaster  \
# 439    True    True     True          False
# 483    True   False     True           True
# 762    True    True     True          False
#
#                                             processor      processor_name  \
# 439        Bionic  A15, Hexa Core, 3.22 GHz Processor         Bionic  A15
# ...

# %%
df.loc[[439, 483, 762], 'ram_capacity'] = [4, 12, 8]

# %%
df['ram_capacity'].isnull().sum()
# Out:
# np.int64(0)

# %%
df['ram_capacity'].value_counts()
# Out:
# ram_capacity
# 8     340
# 6     234
# 4     216
# 12     86
# 3      54
# 2      31
# 16      9
# 1       7
# 18      2
# Name: count, dtype: Int64

# %%
battery_capacity = df['battery'].str.strip().str.extract(r'(\d+)')
battery_capacity
# Out:
#          0
# 0     5000
# 1     5000
# 2     5000
# 3     5000
# 4     5000
# ...    ...
# 1015  5000
# 1016  5000
# 1017  5080
# 1018  5000
# 1019  5000
#
# [979 rows x 1 columns]

# %%
df.insert(21,'battery_capacity',battery_capacity)

# %%
has_fast_charging = df['battery'].str.contains('Fast Charging')
df.insert(22,'has_fast_charging',has_fast_charging)

# %%
fast_charging_watt = df['battery'].str.split('with ').str.get(1).str.split('W').str.get(0)
df.insert(23,'fast_charging_watt',fast_charging_watt)

# %%
temp_df = df[df['fast_charging_watt']=='Fast Charging']
temp_df
# Out:
#       index brand_name                             model   price  rating  \
# 3         5   motorola              Motorola Moto G62 5G   14999    81.0
# 6         8      apple                   Apple iPhone 14   65999    81.0
# 15       17      apple                   Apple iPhone 13   62999    79.0
# 25       27    samsung          Samsung Galaxy S20 FE 5G   31239    88.0
# 27       29      apple           Apple iPhone 14 Pro Max  129990    76.0
# ...     ...        ...                               ...     ...     ...
# 989     991      sharp                   Sharp Aquos R5G   59990    88.0
# 990     992     huawei  Huawei Mate 30 RS Porsche Design  214990     NaN
# 994     996    samsung      Samsung Galaxy A9 Pro (2019)   39990    78.0
# 1018   1020   motorola              Motorola Moto G91 5G   19990    80.0
# 1019   1021    samsung            Samsung Galaxy M52s 5G   24990    74.0
#
#                                                     sim  sim_type  has_3G  \
# ...

# %%
df.loc[temp_df.index,'fast_charging_watt'] = np.nan

# %%
temp_df = df[~df['battery'].str.contains('Fast Charging')]
temp_df
# Out:
#       index brand_name                              model  price  rating  \
# 33       35      apple                    Apple iPhone 11  38999    73.0
# 47       49     realme                         Realme C33   8950    64.0
# 70       72       oppo                          OPPO A17K   9499    62.0
# 75       77     gionee                     Gionee G13 Pro   6190     NaN
# 79       81     xiaomi  Xiaomi Redmi 10A (4GB RAM + 64GB)   8388    66.0
# ...     ...        ...                                ...    ...     ...
# 997     999       poco                           Poco C55   7999    70.0
# 1003   1005       lava                            Lava X3   6999     NaN
# 1005   1007      ikall                          iKall Z18   6799    61.0
# 1006   1008    oukitel                        Oukitel WP9  25899    72.0
# 1012   1014       itel                          itel A23s   4787     NaN
#
#                                       sim  sim_type  has_3G  has_4G  has_5G  \
# ...

# %%
df.loc[temp_df.index,'fast_charging_watt'] = '0'

# %%
df['battery_capacity'] = df['battery_capacity'].astype('Int64')
df['fast_charging_watt'] = df['fast_charging_watt'].astype('Float64')

# %%
display_size = df['display'].str.strip().str.split(' ').str.get(0).astype(float)
display_size
# Out:
# 0       6.70
# 1       6.59
# 2       6.60
# 3       6.55
# 4       6.70
#         ...
# 1015    6.67
# 1016    6.50
# 1017    6.60
# 1018    6.80
# 1019    6.50
# Name: display, Length: 979, dtype: float64

# %%
resolution = df['display'].str.split(',').str.get(1).str.strip().str.split('px').str.get(0).str.strip()
resolution
# Out:
# 0       1440 x 3216
# 1       1080 x 2412
# 2       1080 x 2408
# 3       1080 x 2400
# 4       1080 x 2412
#            ...
# 1015    1080 x 2460
# 1016     720 x 1600
# 1017    1080 x 2460
# 1018    1080 x 2400
# 1019    1080 x 2400
# Name: display, Length: 979, dtype: object

# %%
refresh_rate = df['display'].str.split(',').str.get(2).str.split('Hz').str.get(0).str.strip().apply(lambda x: 60 if pd.isna(x) else x).astype(int)
refresh_rate
# Out:
# 0       120
# 1       120
# 2        90
# 3       120
# 4       120
#        ...
# 1015    120
# 1016     60
# 1017    144
# 1018     60
# 1019     60
# Name: display, Length: 979, dtype: int64

# %%
notch_type = df['display'].str.split('with').str.get(1).str.strip().apply(lambda x: 'Not specified' if pd.isna(x) else x)
notch_type
# Out:
# 0             Punch Hole
# 1             Punch Hole
# 2       Water Drop Notch
# 3             Punch Hole
# 4             Punch Hole
#               ...
# 1015          Punch Hole
# 1016    Water Drop Notch
# 1017          Punch Hole
# 1018          Punch Hole
# 1019    Water Drop Notch
# Name: display, Length: 979, dtype: str

# %%
df.insert(25,'display_size',display_size)
df.insert(26,'resolution',resolution)
df.insert(27,'refresh_rate',refresh_rate)
df.insert(28,'notch_type',notch_type)

# %%
def extract_num_camera(text):
    if 'Quad' in text:
        return 4
    elif 'Triple' in text:
        return 3
    elif 'Dual' in text:
        return 2
    else:
        return 1

# %%
# work with camera cols
nums_rear_cameras = df['camera'].str.split('&').str.get(0).apply(extract_num_camera)
nums_rear_cameras
# Out:
# 0       3
# 1       3
# 2       3
# 3       3
# 4       3
#        ..
# 1015    3
# 1016    3
# 1017    3
# 1018    3
# 1019    3
# Name: camera, Length: 979, dtype: int64

# %%
def Extract_num_camera(text):
    if 'Dual' in text:
        return '2'
    elif 'Missing' in text:
        return 'Missing'
    else:
        return '1'

# %%
nums_front_cameras = df['camera'].str.split('&').str.get(1).fillna('Missing').apply(Extract_num_camera)
nums_front_cameras
# Out:
# 0       1
# 1       1
# 2       1
# 3       1
# 4       1
#        ..
# 1015    1
# 1016    1
# 1017    1
# 1018    1
# 1019    1
# Name: camera, Length: 979, dtype: str

# %%
camera_spec =  df['camera'].str.strip()
camera_spec
# Out:
# 0       50 MP + 48 MP + 32 MP Triple Rear & 16 MP Fron...
# 1       64 MP + 2 MP + 2 MP Triple Rear & 16 MP Front ...
# 2       50 MP + 2 MP + 2 MP Triple Rear & 13 MP Front ...
# 3       50 MP + 8 MP + 2 MP Triple Rear & 16 MP Front ...
# 4       108 MP + 8 MP + 2 MP Triple Rear & 16 MP Front...
#                               ...
# 1015    64 MP + 8 MP + 2 MP Triple Rear & 16 MP Front ...
# 1016    48 MP + 2 MP + Depth Sensor Triple Rear & 8 MP...
# 1017    64 MP + 8 MP + 2 MP Triple Rear & 16 MP Front ...
# 1018    108 MP + 8 MP + 2 MP Triple Rear & 32 MP Front...
# 1019    64 MP + 8 MP + 5 MP Triple Rear & 32 MP Front ...
# Name: camera, Length: 979, dtype: str

# %%
df.insert(30,'camera_spec',camera_spec)
df.insert(31,'nums_rear_cameras',nums_rear_cameras)

# %%
df.insert(32,'nums_front_cameras',nums_front_cameras)

# %%
df[df['nums_front_cameras']=='Missing']
# Out:
#       index brand_name                model   price  rating  \
# 69       71       oppo     Oppo Find N Fold   99990     NaN
# 462     464     xiaomi  Xiaomi Mi Mix Alpha  199990     NaN
# 993     995     huawei        Huawei Mate X  169000     NaN
# 1012   1014       itel            itel A23s    4787     NaN
#
#                                                     sim  sim_type  has_3G  \
# 69              Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC  Dual Sim    True
# 462                  Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi  Dual Sim    True
# 993   Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC, IR Bl...  Dual Sim    True
# 1012                            Dual Sim, 3G, 4G, Wi-Fi  Dual Sim    True
#
#       has_4G  has_5G  has_nfc  has_irblaster  \
# 69      True    True     True          False
# 462     True    True    False          False
# 993     True    True     True           True
# 1012    True   False    False          False
#
# ...

# %%
df.loc[[462,993,1012,69],'nums_front_cameras'] = ['0','0','1','2']

# %%
df['nums_front_cameras'] = df['nums_front_cameras'].astype(int)

# %%
def card_type(text):
    if 'Memory Card Supported' in text:
        return 'supported'
    elif 'Memory Card Not Supported' in text:
        return 'not supported'
    else:
        return 'hybrid'

# %%
# working with card col
card_type = df['card'].str.split(',').str.get(0).str.strip().apply(card_type)
card_type
# Out:
# 0       not supported
# 1              hybrid
# 2           supported
# 3              hybrid
# 4       not supported
#             ...
# 1015    not supported
# 1016        supported
# 1017    not supported
# 1018        supported
# 1019        supported
# Name: card, Length: 979, dtype: str

# %%
card_size = df['card'].str.split(',').str.get(1).str.strip().str.extract(r'(\d+)', expand=False)
card_size
# Out:
# 0       NaN
# 1         1
# 2         1
# 3         1
# 4       NaN
#        ...
# 1015    NaN
# 1016      1
# 1017    NaN
# 1018      1
# 1019      1
# Name: card, Length: 979, dtype: object

# %%
df.insert(34,'card_type',card_type)
df.insert(35,'card_size',card_size)

# %%
temp_df = df[(df['card_size']=='1') | (df['card_size']=='1000')]
temp_df
# Out:
#       index brand_name                                    model  price  \
# 1         3    oneplus                OnePlus Nord CE 2 Lite 5G  19989
# 2         4    samsung                    Samsung Galaxy A14 5G  16499
# 3         5   motorola                     Motorola Moto G62 5G  14999
# 5         7    samsung  Samsung Galaxy F23 5G (6GB RAM + 128GB)  16999
# 10       12     realme                            Realme 10 Pro  18999
# ...     ...        ...                                      ...    ...
# 1002   1004     doogee                               Doogee S99  14999
# 1010   1012     realme  Realme Narzo 50i Prime (4GB RAM + 64GB)   8720
# 1016   1018      honor                              Honor X8 5G  14990
# 1018   1020   motorola                     Motorola Moto G91 5G  19990
# 1019   1021    samsung                   Samsung Galaxy M52s 5G  24990
#
#       rating                                      sim  sim_type  has_3G  \
# ...

# %%
df.loc[temp_df.index,'card_size'] = '1024'

# %%
# working on os cols
os_name = df['os'].str.split(' ').str.get(0).str.strip()
os_name
# Out:
# 0       Android
# 1       Android
# 2       Android
# 3       Android
# 4       Android
#          ...
# 1015    Android
# 1016    Android
# 1017    Android
# 1018    Android
# 1019    Android
# Name: os, Length: 979, dtype: object

# %%
os_version = df['os'].str.split(' ').str.get(1).str.strip('v').str.strip()
os_version
# Out:
# 0       13
# 1       12
# 2       13
# 3       12
# 4       13
#         ..
# 1015    12
# 1016    11
# 1017    12
# 1018    12
# 1019    12
# Name: os, Length: 979, dtype: object

# %%
df.insert(37,'os_name',os_name)
df.insert(38,'os_version',os_version)

# %%
def num_of_cores(text):
    if 'Quad Core' in text:
        return 4
    elif 'Octa Core' in text:
        return 8
    else:
        return 6

# %%
df.loc[[152,263,282,429,448,728],'num_cores'] = ['6','6','6','8','6','6']

# %%
df['num_cores'] = df['num_cores'].apply(num_of_cores)

# %%
print(df['processor_brand'].value_counts().to_string())
# Out:
# processor_brand
# Snapdragon    403
# Helio         201
# Dimensity     177
# Exynos         49
# Bionic         39
# Unisoc         26
# Tiger          24
# Octa           14
# Google          9
# Kirin           7
# Quad            6
# A13             5
#                 4
# Qualcomm        4
# Spreadtrum      4
# SC9863A         2
# Apple           1
# Sanpdragon      1
# Fusion          1
# (28             1
# Samsung         1

# %%
df['processor_brand'] = df['processor_name'].str.split(' ').str.get(0)

# %%
temp_df = df[df['processor_name'].isna()]
temp_df
# Out:
#       index brand_name                                 model  price  rating  \
# 118     120      tesla                        Tesla Pi Phone  69999    83.0
# 143     145        jio                           Jio Phone 3   4499     NaN
# 188     190      ikall                         iKall Z19 Pro   8099    60.0
# 201     203    samsung                    Samsung Galaxy A13  14450    75.0
# 309     311    samsung  Samsung Galaxy A13 (4GB RAM + 128GB)  14999    75.0
# 315     317       itel                          itel S16 Pro   6990     NaN
# 496     498    samsung                    Samsung Galaxy A15  15990    63.0
# 529     531    samsung                    Samsung Galaxy F14  14990    67.0
# 587     589    samsung  Samsung Galaxy A13 (6GB RAM + 128GB)  16499    78.0
# 758     760      ikall                             iKall Z19   7999    61.0
# 778     780      tecno                   Tecno Spark Go 2022   6249    61.0
# ...

# %%
df.loc[temp_df.index,'processor_name'] = ['Unknown','Snapdragon 215','Unknown','Exynos 850','Exynos 850','Unisoc SC9863A','Helio G99','Exynos 1330','Exynos 850','Unknown','Unisoc SC9863A','Unisoc SC7731E','Exynos 2200','Snapdragon 778G','Kirin 710A','Exynos 1380','Helio G85','Snapdragon 450','Unknown','Snapdragon 778G'
]

# %%
df['processor_brand'] = df['processor_name'].str.split(' ').str.get(0)

# %%
df.loc[temp_df.index,'processor_brand'] = np.nan

# %%
temp_df = df[df['os_name'].isna()]
temp_df
# Out:
#      index brand_name                       model   price  rating  \
# 159    161       oppo             Oppo Find N2 5G   94990     NaN
# 306    308    samsung     Samsung Galaxy Z Flip 3   69999    84.0
# 322    324     royole            Royole FlexPai 2  109999    87.0
# 365    367       oppo            OPPO Find N Flip   89990    88.0
# 392    394       oppo           OPPO Find N2 Flip   70990    88.0
# 504    506    samsung  Samsung Galaxy Z Flip 4 5G   89999    88.0
# 570    572         lg                  LG Wing 5G   54999    89.0
# 613    615    oukitel                Oukitel WP21   22990    82.0
# 682    684         lg                LG V60 ThinQ   79990     NaN
# 721    723       asus  Asus ROG Phone 6D Ultimate  107990     NaN
# 726    728     huawei            Huawei Mate Xs 2  162990    89.0
# 894    896     royole         Royole FlexPai 3 5G  149999    87.0
# 993    995     huawei               Huawei Mate X  169000     NaN
#
# ...

# %%
# nan values handeling 
df.loc[temp_df.index,'os'] = ['Android v13', 'Android v11', 'Android v10', 'Android v13', 'Android v13', 'Android v12', 'Android v10', 'Android v12', 'Android v10', 'Android v13', 'HarmonyOS v2.0', 'Android v12', 'Android v9.0']
df.loc[temp_df.index,'os_name'] = ['Android', 'Android', 'Android', 'Android', 'Android', 'Android', 'Android', 'Android', 'Android', 'Android', 'Harmony', 'Android', 'Android']
df.loc[temp_df.index,'os_version'] = ['13', '11', '10', '13', '13', '12', '10', '12', '10', '13', '2', '12', '9']

# %%
# 884,942 rows hav nan os_version
df.loc[[884,942],'os_version'] = ['2','12']

# %%
df.drop(columns=['sim','processor','ram','battery','display','camera','card','os','processor_type','index'],inplace=True)

# %%
# df.to_csv('cleaned_smartphone.csv',index=False)

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# Index: 979 entries, 0 to 1019
# Data columns (total 30 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   brand_name          979 non-null    object
#  1   model               979 non-null    str
#  2   price               979 non-null    int64
#  3   rating              879 non-null    float64
#  4   sim_type            979 non-null    object
#  5   has_3G              979 non-null    bool
#  6   has_4G              979 non-null    bool
#  7   has_5G              979 non-null    bool
#  8   has_nfc             979 non-null    bool
#  9   has_irblaster       979 non-null    bool
#  10  processor_name      979 non-null    object
#  11  processor_brand     959 non-null    object
#  12  num_cores           979 non-null    int64
#  13  processor_speed     937 non-null    float64
#  14  ram_capacity        979 non-null    Int64
#  15  internal_memory     979 non-null    Int64
# ...
