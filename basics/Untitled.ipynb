# %%
str = "Hello my name is Abdul Sahil"
print(type(str))
print(str[-1:])
# Out:
# <class 'str'>
# l

# %%
str = "Hello my name is Abdul Sahil"
print(str[::-1])
# Out:
# lihaS ludbA si eman ym olleH

# %%
str = "Hello my name is Abdul Sahil"
for i in str:
    print(i,end="")
# Out:
# Hello my name is Abdul Sahil

# %%
str = "Hello my name is Abdul Sahil"
print(len(str))
# Out:
# 28

# %%
str1 = "CSE(AI/ml)"
str2 = "section A"
print(str1+ "fnds" +str2)
print(3*str1)
# Out:
# CSE(AI/ml)
# section A
# CSE(AI/ml)CSE(AI/ml)CSE(AI/ml)

# %%
str1 = "CSE(AI/ml)"
str2 = "section A"
print(str1+"\n"+str2)
print(str1+"\t"+str2)
# Out:
# CSE(AI/ml)
# section A
# CSE(AI/ml)	section A

# %%
print('a'>'A')
# Out:
# True

# %%
str = "abDul Sahil"
print(str.capitalize())
print(str.upper())
print(str.lower())
print(str.title()) #
print(str.swapcase()) # convert small case to upper case abd vise-versa
# Out:
# Abdul sahil
# ABDUL SAHIL
# abdul sahil
# Abdul Sahil
# ABdUL sAHIL

# %%
str  = input("Enter the word")
str1 = "aeiouAEIOU"
flage = 0
for i in str:
    if i in str1:
        flage = 1 
        break
if(flage==1):
    print("T")
else:
    print("F")
# Out:
# Enter the word AbdUl
# T

# %%
str = "hello World"
print(len(str))
print(str.strip())
print(str.replace("World","India"))
print(str.find("World"))
# Out:
# 11
# hello World
# hello India
# 6

# %%
str  = input("Enter the marks")
list = str.split(",")
print(list)
print(list[3])
# Out:
# Enter the marks 10,20,30,40,50,60
# ['10', '20', '30', '40', '50', '60']
# 40

# %%
n = int(input("Enter the number:"))
for i in range(1,n+1):
    print(str(i)+"Sahil",end="")
# Out:
# Enter the number: 3
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[84], line 3
#       1 n = int(input("Enter the number:"))
#       2 for i in range(1,n+1):
# ----> 3     print(str(i)+"Sahil",end="")
#
# TypeError: 'str' object is not callable

# %%
n = int(input("Enter the number:"))
for i in range(1,n+1):
    print(i)
# Out:
# Enter the number: 4
# 1
# 2
# 3
# 4
