# %%
# !pip install dtreeviz
# Out:
# Collecting dtreeviz
#   Downloading dtreeviz-2.3.2-py3-none-any.whl.metadata (2.8 kB)
# Collecting graphviz>=0.9 (from dtreeviz)
#   Downloading graphviz-0.21-py3-none-any.whl.metadata (12 kB)
# Requirement already satisfied: pandas in c:\users\moham\appdata\local\programs\python\python314\lib\site-packages (from dtreeviz) (3.0.1)
# Requirement already satisfied: numpy in c:\users\moham\appdata\local\programs\python\python314\lib\site-packages (from dtreeviz) (2.4.2)
# Requirement already satisfied: scikit-learn in c:\users\moham\appdata\local\programs\python\python314\lib\site-packages (from dtreeviz) (1.9.0)
# Requirement already satisfied: matplotlib in c:\users\moham\appdata\local\programs\python\python314\lib\site-packages (from dtreeviz) (3.10.8)
# Collecting colour (from dtreeviz)
#   Downloading colour-0.1.5-py2.py3-none-any.whl.metadata (18 kB)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\moham\appdata\local\programs\python\python314\lib\site-packages (from matplotlib->dtreeviz) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in c:\users\moham\appdata\local\programs\python\python314\lib\site-packages (from matplotlib->dtreeviz) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\moham\appdata\local\programs\python\python314\lib\site-packages (from matplotlib->dtreeviz) (4.61.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\moham\appdata\local\programs\python\python314\lib\site-packages (from matplotlib->dtreeviz) (1.4.9)
# Requirement already satisfied: packaging>=20.0 in c:\users\moham\appdata\roaming\python\python314\site-packages (from matplotlib->dtreeviz) (26.0)
# Requirement already satisfied: pillow>=8 in c:\users\moham\appdata\local\programs\python\python314\lib\site-packages (from matplotlib->dtreeviz) (12.1.1)
# Requirement already satisfied: pyparsing>=3 in c:\users\moham\appdata\local\programs\python\python314\lib\site-packages (from matplotlib->dtreeviz) (3.3.2)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\moham\appdata\roaming\python\python314\site-packages (from matplotlib->dtreeviz) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in c:\users\moham\appdata\roaming\python\python314\site-packages (from python-dateutil>=2.7->matplotlib->dtreeviz) (1.17.0)
# Requirement already satisfied: tzdata in c:\users\moham\appdata\local\programs\python\python314\lib\site-packages (from pandas->dtreeviz) (2025.3)
# Requirement already satisfied: scipy>=1.10.0 in c:\users\moham\appdata\local\programs\python\python314\lib\site-packages (from scikit-learn->dtreeviz) (1.17.1)
# Requirement already satisfied: joblib>=1.4.0 in c:\users\moham\appdata\local\programs\python\python314\lib\site-packages (from scikit-learn->dtreeviz) (1.5.3)
# Requirement already satisfied: narwhals>=2.0.1 in c:\users\moham\appdata\local\programs\python\python314\lib\site-packages (from scikit-learn->dtreeviz) (2.22.1)
# Requirement already satisfied: threadpoolctl>=3.5.0 in c:\users\moham\appdata\local\programs\python\python314\lib\site-packages (from scikit-learn->dtreeviz) (3.6.0)
# Downloading dtreeviz-2.3.2-py3-none-any.whl (102 kB)
# Downloading graphviz-0.21-py3-none-any.whl (47 kB)
# Downloading colour-0.1.5-py2.py3-none-any.whl (23 kB)
# Installing collected packages: colour, graphviz, dtreeviz
#
#    ------------- -------------------------- 1/3 [graphviz]
#    ------------- -------------------------- 1/3 [graphviz]
#    ------------- -------------------------- 1/3 [graphviz]
#    -------------------------- ------------- 2/3 [dtreeviz]
#    -------------------------- ------------- 2/3 [dtreeviz]
#    -------------------------- ------------- 2/3 [dtreeviz]
#    -------------------------- ------------- 2/3 [dtreeviz]
#    -------------------------- ------------- 2/3 [dtreeviz]
#    ---------------------------------------- 3/3 [dtreeviz]
#
# Successfully installed colour-0.1.5 dtreeviz-2.3.2 graphviz-0.21
# [notice] A new release of pip is available: 25.2 -> 26.2.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import numpy as np
import pandas as pd

# %%
from sklearn.datasets import *
from dtreeviz.trees import *
from IPython.display import Image, display_svg, SVG
from sklearn import tree

# %%
clas = tree.DecisionTreeClassifier(max_depth=2)
iris = load_iris()

X_train = iris.data
y_train = iris.target
clas.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier(max_depth=2)

# %%
from sklearn.tree import plot_tree
plot_tree(clas)
# Out:
# [Text(0.4, 0.8333333333333334, 'x[2] <= 2.45\ngini = 0.667\nsamples = 150\nvalue = [50, 50, 50]'),
#  Text(0.2, 0.5, 'gini = 0.0\nsamples = 50\nvalue = [50, 0, 0]'),
#  Text(0.30000000000000004, 0.6666666666666667, 'True  '),
#  Text(0.6, 0.5, 'x[3] <= 1.75\ngini = 0.5\nsamples = 100\nvalue = [0, 50, 50]'),
#  Text(0.5, 0.6666666666666667, '  False'),
#  Text(0.4, 0.16666666666666666, 'gini = 0.168\nsamples = 54\nvalue = [0, 49, 5]'),
#  Text(0.8, 0.16666666666666666, 'gini = 0.043\nsamples = 46\nvalue = [0, 1, 45]')]

# %% [markdown]
# # 1. Classification

# %%
from dtreeviz import model

viz_model = model(clas,
                   X_train=X_train,
                   y_train=y_train,
                   feature_names=iris.feature_names,
                   target_name="species",
                   class_names=["setosa", "versicolor", "virginica"])

viz_model.view()

# %% [markdown]
# # 2. Regression

# %%
from sklearn.datasets import fetch_california_housing

california = fetch_california_housing()

X_train = california.data
y_train = california.target

regr = tree.DecisionTreeRegressor(max_depth=1)
regr.fit(X_train, y_train)

viz_model = dtreeviz.model(regr,
                            X_train=X_train,
                            y_train=y_train,
                            target_name='price',
                            feature_names=california.feature_names)

viz_model.view(scale=2)

# %% [markdown]
# # 3. Horizontal Decision Tree

# %%
viz = dtreeviz(clas, 
               X_train,
               y_train,
               target_name='price',
               feature_names=iris.feature_names, 
               class_names=["setosa", "versicolor", "virginica"], 
               scale = 1.5,
               orientation='LR')
viz
# Out:
# /usr/local/lib/python3.7/dist-packages/numpy/core/_asarray.py:83: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   return array(a, dtype, copy=False, order=order)

# %% [markdown]
# # 4. Show prediction path

# %%
clas = tree.DecisionTreeClassifier()  
iris = load_iris()

X_train = iris.data
y_train = iris.target
clas.fit(X_train, y_train)

X = iris.data[np.random.randint(0, len(iris.data)),:]

viz = dtreeviz(clas, 
               X_train,
               y_train,
               feature_names=iris.feature_names, 
               class_names=["setosa", "versicolor", "virginica"], 
               X=X)
viz
# Out:
# /usr/local/lib/python3.7/dist-packages/numpy/core/_asarray.py:83: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   return array(a, dtype, copy=False, order=order)

# %%
X
# Out:
# array([5.5, 2.3, 4. , 1.3])

# %% [markdown]
# # 5. Show node number

# %%
viz = dtreeviz(clas, 
               X_train,
               y_train,
               target_name='price',
               feature_names=iris.feature_names, 
               class_names=["setosa", "versicolor", "virginica"], 
               histtype= 'barstacked',
               scale = 1.5,
               orientation='LR',
               show_node_labels=True)
viz
# Out:
# /usr/local/lib/python3.7/dist-packages/numpy/core/_asarray.py:83: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   return array(a, dtype, copy=False, order=order)

# %% [markdown]
# # 6. Without Any graphs

# %%
viz = dtreeviz(clas, 
               X_train,
               y_train,
               target_name='price',
               feature_names=iris.feature_names, 
               class_names=["setosa", "versicolor", "virginica"], 
               histtype= 'barstacked',
               scale = 1.5,
               orientation='LR',
               fancy=False)
viz

# %% [markdown]
# # 7. Show just prediction path, nothing else

# %%
clas = tree.DecisionTreeClassifier()  
iris = load_iris()

X_train = iris.data
y_train = iris.target
clas.fit(X_train, y_train)

X = iris.data[np.random.randint(0, len(iris.data)),:]

viz = dtreeviz(clas, 
               X_train,
               y_train,
               target_name='price',
               feature_names=iris.feature_names, 
               class_names=["setosa", "versicolor", "virginica"], 
               X=X,
               show_just_path=True)
viz
# Out:
# /usr/local/lib/python3.7/dist-packages/numpy/core/_asarray.py:83: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   return array(a, dtype, copy=False, order=order)

# %% [markdown]
# # 8. Prediction Path in Plain english

# %%
print(explain_prediction_path(clas, X, feature_names=iris.feature_names, explanation_type="plain_english"))
# Out:
# sepal length (cm) < 5.95
# petal length (cm) < 4.85
# 1.75 <= petal width (cm)

# %% [markdown]
# # 9. Feature Importance

# %%
print(explain_prediction_path(clas, X, feature_names=iris.feature_names, explanation_type="sklearn_default"))
# Out:
# AxesSubplot(0.125,0.125;0.775x0.755)

# %% [markdown]
# # 10. Univariate Regression

# %%
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.tree import DecisionTreeRegressor
from dtreeviz.trees import *

df_cars = pd.read_csv("cars.csv")
X, y = df_cars[['WGT']], df_cars['MPG']

dt = DecisionTreeRegressor(max_depth=3, criterion="mae")
dt.fit(X, y)

fig = plt.figure()
ax = fig.gca()
rtreeviz_univar(dt, X, y, 'WGT', 'MPG', ax=ax)
plt.show()

# %% [markdown]
# # 11. 3-D Regression

# %%
df_cars = pd.read_csv("cars.csv")

df_cars
# Out:
#       MPG  CYL    ENG   WGT
# 0    18.0    8  307.0  3504
# 1    15.0    8  350.0  3693
# 2    18.0    8  318.0  3436
# 3    16.0    8  304.0  3433
# 4    17.0    8  302.0  3449
# ..    ...  ...    ...   ...
# 387  27.0    4  140.0  2790
# 388  44.0    4   97.0  2130
# 389  32.0    4  135.0  2295
# 390  28.0    4  120.0  2625
# 391  31.0    4  119.0  2720
#
# [392 rows x 4 columns]

# %%
from mpl_toolkits.mplot3d import Axes3D
from sklearn.tree import DecisionTreeRegressor
from dtreeviz.trees import *


X = df_cars[['WGT','ENG']]
y = df_cars['MPG']

dt = DecisionTreeRegressor(max_depth=3, criterion="mae")
dt.fit(X, y)

figsize = (6,5)
fig = plt.figure(figsize=figsize)
ax = fig.add_subplot(111, projection='3d')

t = rtreeviz_bivar_3D(dt,
                      X, y,
                      feature_names=['Vehicle Weight', 'Horse Power'],
                      target_name='MPG',
                      fontsize=14,
                      elev=20,
                      azim=25,
                      dist=8.2,
                      show={'splits','title'},
                      ax=ax)
plt.show()
